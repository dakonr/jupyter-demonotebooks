# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Task_2_data.csv", sep=";", header=0)

# %%
data
# Out:
#    kmstand  preis
# 0       14   11.7
# 1        9   12.0
# 2       30    9.6
# 3       37    9.3
# 4       17   10.8
# 5        6   12.3
# 6       20   10.2
# 7       27   10.5

# %%
x = data.kmstand.values
y = data.preis.values

# %%
x = x.reshape(len(x), 1)
y = y.reshape(len(y), 1)

# %%
model = LinearRegression()

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
r_sq = model.score(x, y)
intercept = model.intercept_
slope = model.coef_
print(f"intercept: {intercept}")
print(f"slope: {slope}")
print(f"coeff {r_sq}")
# Out:
# intercept: [12.78]
# slope: [[-0.099]]
# coeff 0.9075

# %%
# plot
sns.set()
plt.scatter(x, y, alpha=0.5)
plt.xlabel("KM Stand in Tkm")
plt.ylabel("Preis (in T€)")
t = (min(x), max(x))
plt.plot(t, model.predict(t), "-r")
ax = plt.gca()
plt.text(
    0.20,
    0.05,
    "R² = " + str(round(r_sq, 2)),
    horizontalalignment="right",
    verticalalignment="center",
    transform=ax.transAxes,
)
plt.show()

# %%
sns.jointplot(x="kmstand", y="preis", data=data, kind='reg');

# %%
sns.regplot(x="kmstand", y="preis", data=data);
